# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
px = yf.download('AAPL', start = "2013-12-01", end = "2024-02-01")
px
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2013-12-02   17.175100   19.686787   20.154642   19.672144   19.928572
# 2013-12-03   17.645266   20.225714   20.227858   19.917143   19.939285
# 2013-12-04   17.604143   20.178572   20.328215   20.029285   20.196428
# 2013-12-05   17.694496   20.282143   20.540714   20.228930   20.451786
# 2013-12-06   17.448971   20.000713   20.241072   19.984644   20.206785
# ...                ...         ...         ...         ...         ...
# 2024-01-25  193.223389  194.169998  196.270004  193.110001  195.220001
# 2024-01-26  191.481903  192.419998  194.759995  191.940002  194.270004
# 2024-01-29  190.795288  191.729996  192.199997  189.580002  192.009995
# 2024-01-30  187.123276  188.039993  191.800003  187.470001  190.940002
# 2024-01-31  183.501022  184.399994  187.100006  184.350006  187.039993
#
# Price          Volume
# Ticker           AAPL
# Date
# 2013-12-02  472544800
# 2013-12-03  450968000
# 2013-12-04  377809600
# 2013-12-05  447580000
# 2013-12-06  344352400
# ...               ...
# 2024-01-25   54822100
# 2024-01-26   44594000
# 2024-01-29   47145600
# 2024-01-30   55859400
# 2024-01-31   55467800
#
# [2558 rows x 6 columns]

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.
#
# Start by getting a sample of Information Technology stock tickers by applying subindexing and converting the "ticker" column from a pandas object to a list.

# %%
# Load all tickers
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file)

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %%
idx_tech = tickers['GICS Sector'] == 'Information Technology'
tech_sector = tickers[idx_tech]

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
tech_tickers = tech_sector['ticker'].to_list()

# %%
tech_raw_dt = yf.download(tech_tickers, start = "2000-01-01", end = "2025-01-26")
# Out:
# [*********************100%***********************]  64 of 64 completed

# %% [markdown]
# The data that we downloaded combines several stocks and prices into a single row. We want to parse this arrangement into a dataframe that contains observations about a single stock on a given day per row. To do this, we can use the function [`stack()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html) and re-arrange the indices.

# %%
# First, check what tech_raw_dt.stack() looks like.
tech_raw_dt.stack(future_stack=True).reset_index()
# Out:
# Price        Date Ticker   Adj Close       Close        High         Low  \
# 0      2000-01-03   AAPL    0.843076    0.999442    1.004464    0.907924
# 1      2000-01-03    ACN         NaN         NaN         NaN         NaN
# 2      2000-01-03   ADBE   16.274673   16.390625   16.875000   16.062500
# 3      2000-01-03    ADI   28.095701   45.093750   46.937500   44.000000
# 4      2000-01-03   ADSK    8.052906    8.343750    8.656250    8.031250
# ...           ...    ...         ...         ...         ...         ...
# 403451 2025-01-24    TXN  184.158173  185.520004  191.500000  185.029999
# 403452 2025-01-24    TYL  591.929993  591.929993  594.969971  590.210022
# 403453 2025-01-24   VRSN  210.729996  210.729996  210.880005  206.009995
# 403454 2025-01-24    WDC   67.410004   67.410004   69.440002   67.360001
# 403455 2025-01-24   ZBRA  414.609985  414.609985  420.079987  413.739990
#
# Price         Open       Volume
# 0         0.936384  535796800.0
# 1              NaN          NaN
# 2        16.812500    7384400.0
# 3        46.750000    3655600.0
# 4         8.500000    2845600.0
# ...            ...          ...
# 403451  190.000000   15856600.0
# 403452  591.400024     155300.0
# 403453  206.020004     563300.0
# 403454   68.910004    6046500.0
# 403455  419.059998     258900.0
#
# [403456 rows x 8 columns]

# %%
tech_dt = (tech_raw_dt
           .stack(future_stack=True)
           .reset_index()
           .sort_values(['Ticker', 'Date']))
tech_dt.columns.name = None

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
tech_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({tech_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((403456, 8))csv took 4.793243646621704 seconds.
# Csv file size 41.765789 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd

# %%
px_dd = dd.from_pandas(tech_dt, npartitions = len(tech_tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({tech_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((403456, 8)) to parquet took 0.7188940048217773 seconds.
# Parquet file size 16.534095 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in tech_dt['Ticker'].unique():
    ticker_dt = tech_dt[tech_dt['Ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("Ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
# Out:
# C:\Users\Teresa - School\AppData\Local\Temp\ipykernel_25968\3086392435.py:1: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                           Date Adj Close    Close     High      Low     Open   Volume   Year Close_lag_1  Returns
# npartitions=64
# AAPL            datetime64[ns]   float64  float64  float64  float64  float64  float64  int32     float64  float64
# ACN                        ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ...                        ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                       ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                       ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# Dask Name: assign, 14 graph layers

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#              Date   Adj Close       Close        High         Low        Open  \
# Ticker
# AAPL   2000-01-03    0.843076    0.999442    1.004464    0.907924    0.936384
# AAPL   2000-01-04    0.771997    0.915179    0.987723    0.903460    0.966518
# AAPL   2000-01-05    0.783293    0.928571    0.987165    0.919643    0.926339
# AAPL   2000-01-06    0.715508    0.848214    0.955357    0.848214    0.947545
# AAPL   2000-01-07    0.749402    0.888393    0.901786    0.852679    0.861607
# ...           ...         ...         ...         ...         ...         ...
# ZBRA   2025-01-17  405.709991  405.709991  407.290009  402.290009  406.040009
# ZBRA   2025-01-21  418.070007  418.070007  419.850006  407.619995  407.619995
# ZBRA   2025-01-22  420.570007  420.570007  427.760010  419.589996  425.239990
# ZBRA   2025-01-23  421.109985  421.109985  422.290009  414.450012  417.619995
# ZBRA   2025-01-24  414.609985  414.609985  420.079987  413.739990  419.059998
#
#              Volume  Year  Close_lag_1   Returns
# Ticker
# AAPL    535796800.0  2000          NaN       NaN
# AAPL    512377600.0  2000     0.999442 -0.084310
# AAPL    778321600.0  2000     0.915179  0.014633
# AAPL    767972800.0  2000     0.928571 -0.086538
# AAPL    460734400.0  2000     0.848214  0.047369
# ...             ...   ...          ...       ...
# ZBRA       270600.0  2025   402.720001  0.007424
# ZBRA       446000.0  2025   405.709991  0.030465
# ZBRA       497500.0  2025   418.070007  0.005980
# ZBRA       377100.0  2025   420.570007  0.001284
# ZBRA       258900.0  2025   421.109985 -0.015435
#
# [403456 rows x 10 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# The `DataManager` class in `./05_src/data_manager.py` is a simple implementation of the ideas and code discussed in this notebook. The lines below will download data for about 500 stocks from the S&P500. Using this data a few features will be created and stored in the features data set.
#
# First, instantiate an object of class `DataManager`.

# %%
from data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.download_all()
# Out:
# 2025-02-08 16:34:26,139, data_manager.py, 42, INFO, Getting price data for all tickers.
# 2025-02-08 16:34:26,141, data_manager.py, 51, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2025-02-08 16:34:26,155, data_manager.py, 57, INFO, Processing all tickers
# 2025-02-08 16:34:26,158, data_manager.py, 70, INFO, Processing ticker ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
# 2025-02-08 16:34:26,161, data_manager.py, 100, INFO, Getting stock price data for ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS'] from 2000-01-01 to 2025-02-08
# [*********************100%***********************]  503 of 503 completed
#
# 8 Failed downloads:
# ['FLT', 'BRK.B', 'PXD', 'MRO', 'PEAK', 'WRK']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-01-01 -> 2025-02-08)')
# ['CPT']: ConnectionError(ReadTimeoutError("HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out."))
# 2025-02-08 16:36:03,943, data_manager.py, 80, INFO, Saving data by year
# 2025-02-08 16:36:04,522, data_manager.py, 83, INFO, Saving data for A
# 2025-02-08 16:36:06,758, data_manager.py, 83, INFO, Saving data for AAL
# 2025-02-08 16:36:08,930, data_manager.py, 83, INFO, Saving data for AAPL
# 2025-02-08 16:36:11,738, data_manager.py, 83, INFO, Saving data for ABBV
# 2025-02-08 16:36:14,506, data_manager.py, 83, INFO, Saving data for ABNB
# 2025-02-08 16:36:19,610, data_manager.py, 83, INFO, Saving data for ABT
# 2025-02-08 16:36:23,593, data_manager.py, 83, INFO, Saving data for ACGL
# 2025-02-08 16:36:26,391, data_manager.py, 83, INFO, Saving data for ACN
# 2025-02-08 16:36:29,778, data_manager.py, 83, INFO, Saving data for ADBE
# 2025-02-08 16:36:34,300, data_manager.py, 83, INFO, Saving data for ADI
# 2025-02-08 16:36:38,965, data_manager.py, 83, INFO, Saving data for ADM
# 2025-02-08 16:36:42,896, data_manager.py, 83, INFO, Saving data for ADP
# 2025-02-08 16:36:45,456, data_manager.py, 83, INFO, Saving data for ADSK
# 2025-02-08 16:36:48,233, data_manager.py, 83, INFO, Saving data for AEE
# 2025-02-08 16:36:52,510, data_manager.py, 83, INFO, Saving data for AEP
# 2025-02-08 16:36:57,638, data_manager.py, 83, INFO, Saving data for AES
# 2025-02-08 16:37:02,162, data_manager.py, 83, INFO, Saving data for AFL
# 2025-02-08 16:37:06,035, data_manager.py, 83, INFO, Saving data for AIG
# 2025-02-08 16:37:08,399, data_manager.py, 83, INFO, Saving data for AIZ
# 2025-02-08 16:37:11,044, data_manager.py, 83, INFO, Saving data for AJG
# 2025-02-08 16:37:15,794, data_manager.py, 83, INFO, Saving data for AKAM
# 2025-02-08 16:37:20,536, data_manager.py, 83, INFO, Saving data for ALB
# 2025-02-08 16:37:24,750, data_manager.py, 83, INFO, Saving data for ALGN
# 2025-02-08 16:37:27,581, data_manager.py, 83, INFO, Saving data for ALL
# 2025-02-08 16:37:30,112, data_manager.py, 83, INFO, Saving data for ALLE
# 2025-02-08 16:37:34,322, data_manager.py, 83, INFO, Saving data for AMAT
# 2025-02-08 16:37:39,015, data_manager.py, 83, INFO, Saving data for AMCR
# 2025-02-08 16:37:43,449, data_manager.py, 83, INFO, Saving data for AMD
# 2025-02-08 16:37:47,318, data_manager.py, 83, INFO, Saving data for AME
# 2025-02-08 16:37:49,712, data_manager.py, 83, INFO, Saving data for AMGN
# 2025-02-08 16:37:52,087, data_manager.py, 83, INFO, Saving data for AMP
# 2025-02-08 16:37:56,324, data_manager.py, 83, INFO, Saving data for AMT
# 2025-02-08 16:38:01,199, data_manager.py, 83, INFO, Saving data for AMZN
# 2025-02-08 16:38:05,741, data_manager.py, 83, INFO, Saving data for ANET
# 2025-02-08 16:38:09,204, data_manager.py, 83, INFO, Saving data for ANSS
# 2025-02-08 16:38:11,765, data_manager.py, 83, INFO, Saving data for AON
# 2025-02-08 16:38:14,241, data_manager.py, 83, INFO, Saving data for AOS
# 2025-02-08 16:38:18,800, data_manager.py, 83, INFO, Saving data for APA
# 2025-02-08 16:38:23,261, data_manager.py, 83, INFO, Saving data for APD
# 2025-02-08 16:38:27,553, data_manager.py, 83, INFO, Saving data for APH
# 2025-02-08 16:38:30,656, data_manager.py, 83, INFO, Saving data for APTV
# 2025-02-08 16:38:33,056, data_manager.py, 83, INFO, Saving data for ARE
# 2025-02-08 16:38:36,356, data_manager.py, 83, INFO, Saving data for ATO
# 2025-02-08 16:38:40,827, data_manager.py, 83, INFO, Saving data for AVB
# 2025-02-08 16:38:45,451, data_manager.py, 83, INFO, Saving data for AVGO
# 2025-02-08 16:38:49,343, data_manager.py, 83, INFO, Saving data for AVY
# 2025-02-08 16:38:51,985, data_manager.py, 83, INFO, Saving data for AWK
# 2025-02-08 16:38:54,418, data_manager.py, 83, INFO, Saving data for AXON
# 2025-02-08 16:38:58,439, data_manager.py, 83, INFO, Saving data for AXP
# 2025-02-08 16:39:02,684, data_manager.py, 83, INFO, Saving data for AZO
# 2025-02-08 16:39:07,069, data_manager.py, 83, INFO, Saving data for BA
# 2025-02-08 16:39:10,507, data_manager.py, 83, INFO, Saving data for BAC
# 2025-02-08 16:39:12,997, data_manager.py, 83, INFO, Saving data for BALL
# 2025-02-08 16:39:15,988, data_manager.py, 83, INFO, Saving data for BAX
# 2025-02-08 16:39:20,187, data_manager.py, 83, INFO, Saving data for BBWI
# 2025-02-08 16:39:24,938, data_manager.py, 83, INFO, Saving data for BBY
# 2025-02-08 16:39:28,806, data_manager.py, 83, INFO, Saving data for BDX
# 2025-02-08 16:39:31,775, data_manager.py, 83, INFO, Saving data for BEN
# 2025-02-08 16:39:34,136, data_manager.py, 83, INFO, Saving data for BF.B
# 2025-02-08 16:39:37,709, data_manager.py, 83, INFO, Saving data for BG
# 2025-02-08 16:39:42,100, data_manager.py, 83, INFO, Saving data for BIIB
# 2025-02-08 16:39:46,632, data_manager.py, 83, INFO, Saving data for BIO
# 2025-02-08 16:39:50,459, data_manager.py, 83, INFO, Saving data for BK
# 2025-02-08 16:39:52,986, data_manager.py, 83, INFO, Saving data for BKNG
# 2025-02-08 16:39:55,318, data_manager.py, 83, INFO, Saving data for BKR
# 2025-02-08 16:39:59,654, data_manager.py, 83, INFO, Saving data for BLDR
# 2025-02-08 16:40:04,260, data_manager.py, 83, INFO, Saving data for BLK
# 2025-02-08 16:40:08,568, data_manager.py, 83, INFO, Saving data for BMY
# 2025-02-08 16:40:11,719, data_manager.py, 83, INFO, Saving data for BR
# 2025-02-08 16:40:14,129, data_manager.py, 83, INFO, Saving data for BRK.B
# 2025-02-08 16:40:17,014, data_manager.py, 83, INFO, Saving data for BRO
# 2025-02-08 16:40:21,384, data_manager.py, 83, INFO, Saving data for BSX
# 2025-02-08 16:40:25,708, data_manager.py, 83, INFO, Saving data for BWA
# 2025-02-08 16:40:30,062, data_manager.py, 83, INFO, Saving data for BX
# 2025-02-08 16:40:32,621, data_manager.py, 83, INFO, Saving data for BXP
# 2025-02-08 16:40:35,014, data_manager.py, 83, INFO, Saving data for C
# 2025-02-08 16:40:38,685, data_manager.py, 83, INFO, Saving data for CAG
# 2025-02-08 16:40:43,286, data_manager.py, 83, INFO, Saving data for CAH
# 2025-02-08 16:40:47,606, data_manager.py, 83, INFO, Saving data for CARR
# 2025-02-08 16:40:51,582, data_manager.py, 83, INFO, Saving data for CAT
# 2025-02-08 16:40:54,084, data_manager.py, 83, INFO, Saving data for CB
# 2025-02-08 16:40:56,427, data_manager.py, 83, INFO, Saving data for CBOE
# 2025-02-08 16:41:00,562, data_manager.py, 83, INFO, Saving data for CBRE
# 2025-02-08 16:41:05,048, data_manager.py, 83, INFO, Saving data for CCI
# 2025-02-08 16:41:09,482, data_manager.py, 83, INFO, Saving data for CCL
# 2025-02-08 16:41:12,569, data_manager.py, 83, INFO, Saving data for CDNS
# 2025-02-08 16:41:16,288, data_manager.py, 83, INFO, Saving data for CDW
# 2025-02-08 16:41:20,091, data_manager.py, 83, INFO, Saving data for CE
# 2025-02-08 16:41:24,434, data_manager.py, 83, INFO, Saving data for CEG
# 2025-02-08 16:41:28,683, data_manager.py, 83, INFO, Saving data for CF
# 2025-02-08 16:41:32,538, data_manager.py, 83, INFO, Saving data for CFG
# 2025-02-08 16:41:35,200, data_manager.py, 83, INFO, Saving data for CHD
# 2025-02-08 16:41:37,642, data_manager.py, 83, INFO, Saving data for CHRW
# 2025-02-08 16:41:41,652, data_manager.py, 83, INFO, Saving data for CHTR
# 2025-02-08 16:41:46,004, data_manager.py, 83, INFO, Saving data for CI
# 2025-02-08 16:41:50,393, data_manager.py, 83, INFO, Saving data for CINF
# 2025-02-08 16:41:53,731, data_manager.py, 83, INFO, Saving data for CL
# 2025-02-08 16:41:56,498, data_manager.py, 83, INFO, Saving data for CLX
# 2025-02-08 16:41:59,793, data_manager.py, 83, INFO, Saving data for CMA
# 2025-02-08 16:42:04,025, data_manager.py, 83, INFO, Saving data for CMCSA
# 2025-02-08 16:42:08,079, data_manager.py, 83, INFO, Saving data for CME
# 2025-02-08 16:42:12,072, data_manager.py, 83, INFO, Saving data for CMG
# 2025-02-08 16:42:14,775, data_manager.py, 83, INFO, Saving data for CMI
# 2025-02-08 16:42:17,323, data_manager.py, 83, INFO, Saving data for CMS
# 2025-02-08 16:42:21,518, data_manager.py, 83, INFO, Saving data for CNC
# 2025-02-08 16:42:26,414, data_manager.py, 83, INFO, Saving data for CNP
# 2025-02-08 16:42:30,410, data_manager.py, 83, INFO, Saving data for COF
# 2025-02-08 16:42:33,630, data_manager.py, 83, INFO, Saving data for COO
# 2025-02-08 16:42:36,209, data_manager.py, 83, INFO, Saving data for COP
# 2025-02-08 16:42:39,549, data_manager.py, 83, INFO, Saving data for COR
# 2025-02-08 16:42:44,068, data_manager.py, 83, INFO, Saving data for COST
# 2025-02-08 16:42:48,509, data_manager.py, 83, INFO, Saving data for CPB
# 2025-02-08 16:42:52,224, data_manager.py, 83, INFO, Saving data for CPRT
# 2025-02-08 16:42:55,098, data_manager.py, 83, INFO, Saving data for CPT
# 2025-02-08 16:42:58,449, data_manager.py, 83, INFO, Saving data for CRL
# 2025-02-08 16:43:01,518, data_manager.py, 83, INFO, Saving data for CRM
# 2025-02-08 16:43:04,311, data_manager.py, 83, INFO, Saving data for CSCO
# 2025-02-08 16:43:06,970, data_manager.py, 83, INFO, Saving data for CSGP
# 2025-02-08 16:43:09,651, data_manager.py, 83, INFO, Saving data for CSX
# 2025-02-08 16:43:12,266, data_manager.py, 83, INFO, Saving data for CTAS
# 2025-02-08 16:43:14,879, data_manager.py, 83, INFO, Saving data for CTLT
# 2025-02-08 16:43:17,676, data_manager.py, 83, INFO, Saving data for CTRA
# 2025-02-08 16:43:20,203, data_manager.py, 83, INFO, Saving data for CTSH
# 2025-02-08 16:43:22,701, data_manager.py, 83, INFO, Saving data for CTVA
# 2025-02-08 16:43:25,280, data_manager.py, 83, INFO, Saving data for CVS
# 2025-02-08 16:43:27,912, data_manager.py, 83, INFO, Saving data for CVX
# 2025-02-08 16:43:30,145, data_manager.py, 83, INFO, Saving data for CZR
# 2025-02-08 16:43:32,712, data_manager.py, 83, INFO, Saving data for D
# 2025-02-08 16:43:36,583, data_manager.py, 83, INFO, Saving data for DAL
# 2025-02-08 16:43:40,684, data_manager.py, 83, INFO, Saving data for DAY
# 2025-02-08 16:43:44,854, data_manager.py, 83, INFO, Saving data for DD
# 2025-02-08 16:43:48,387, data_manager.py, 83, INFO, Saving data for DE
# 2025-02-08 16:43:50,973, data_manager.py, 83, INFO, Saving data for DFS
# 2025-02-08 16:43:53,505, data_manager.py, 83, INFO, Saving data for DG
# 2025-02-08 16:43:56,013, data_manager.py, 83, INFO, Saving data for DGX
# 2025-02-08 16:43:58,151, data_manager.py, 83, INFO, Saving data for DHI
# 2025-02-08 16:44:00,612, data_manager.py, 83, INFO, Saving data for DHR
# 2025-02-08 16:44:04,252, data_manager.py, 83, INFO, Saving data for DIS
# 2025-02-08 16:44:07,124, data_manager.py, 83, INFO, Saving data for DLR
# 2025-02-08 16:44:09,643, data_manager.py, 83, INFO, Saving data for DLTR
# 2025-02-08 16:44:13,682, data_manager.py, 83, INFO, Saving data for DOV
# 2025-02-08 16:44:18,019, data_manager.py, 83, INFO, Saving data for DOW
# 2025-02-08 16:44:22,390, data_manager.py, 83, INFO, Saving data for DPZ
# 2025-02-08 16:44:25,498, data_manager.py, 83, INFO, Saving data for DRI
# 2025-02-08 16:44:27,941, data_manager.py, 83, INFO, Saving data for DTE
# 2025-02-08 16:44:30,415, data_manager.py, 83, INFO, Saving data for DUK
# 2025-02-08 16:44:34,894, data_manager.py, 83, INFO, Saving data for DVA
# 2025-02-08 16:44:39,456, data_manager.py, 83, INFO, Saving data for DVN
# 2025-02-08 16:44:43,927, data_manager.py, 83, INFO, Saving data for DXCM
# 2025-02-08 16:44:47,712, data_manager.py, 83, INFO, Saving data for EA
# 2025-02-08 16:44:49,964, data_manager.py, 83, INFO, Saving data for EBAY
# 2025-02-08 16:44:52,283, data_manager.py, 83, INFO, Saving data for ECL
# 2025-02-08 16:44:56,760, data_manager.py, 83, INFO, Saving data for ED
# 2025-02-08 16:45:01,224, data_manager.py, 83, INFO, Saving data for EFX
# 2025-02-08 16:45:05,537, data_manager.py, 83, INFO, Saving data for EG
# 2025-02-08 16:45:08,815, data_manager.py, 83, INFO, Saving data for EIX
# 2025-02-08 16:45:11,522, data_manager.py, 83, INFO, Saving data for EL
# 2025-02-08 16:45:14,057, data_manager.py, 83, INFO, Saving data for ELV
# 2025-02-08 16:45:18,658, data_manager.py, 83, INFO, Saving data for EMN
# 2025-02-08 16:45:23,079, data_manager.py, 83, INFO, Saving data for EMR
# 2025-02-08 16:45:27,233, data_manager.py, 83, INFO, Saving data for ENPH
# 2025-02-08 16:45:31,261, data_manager.py, 83, INFO, Saving data for EOG
# 2025-02-08 16:45:35,888, data_manager.py, 83, INFO, Saving data for EPAM
# 2025-02-08 16:45:40,907, data_manager.py, 83, INFO, Saving data for EQIX
# 2025-02-08 16:45:45,376, data_manager.py, 83, INFO, Saving data for EQR
# 2025-02-08 16:45:49,974, data_manager.py, 83, INFO, Saving data for EQT
# 2025-02-08 16:45:53,414, data_manager.py, 83, INFO, Saving data for ES
# 2025-02-08 16:45:55,864, data_manager.py, 83, INFO, Saving data for ESS
# 2025-02-08 16:45:58,280, data_manager.py, 83, INFO, Saving data for ETN
# 2025-02-08 16:46:02,496, data_manager.py, 83, INFO, Saving data for ETR
# 2025-02-08 16:46:07,012, data_manager.py, 83, INFO, Saving data for ETSY
# 2025-02-08 16:46:11,392, data_manager.py, 83, INFO, Saving data for EVRG
# 2025-02-08 16:46:15,125, data_manager.py, 83, INFO, Saving data for EW
# 2025-02-08 16:46:17,553, data_manager.py, 83, INFO, Saving data for EXC
# 2025-02-08 16:46:20,417, data_manager.py, 83, INFO, Saving data for EXPD
# 2025-02-08 16:46:24,768, data_manager.py, 83, INFO, Saving data for EXPE
# 2025-02-08 16:46:29,317, data_manager.py, 83, INFO, Saving data for EXR
# 2025-02-08 16:46:33,448, data_manager.py, 83, INFO, Saving data for F
# 2025-02-08 16:46:36,574, data_manager.py, 83, INFO, Saving data for FANG
# 2025-02-08 16:46:39,430, data_manager.py, 83, INFO, Saving data for FAST
# 2025-02-08 16:46:43,556, data_manager.py, 83, INFO, Saving data for FCX
# 2025-02-08 16:46:47,883, data_manager.py, 83, INFO, Saving data for FDS
# 2025-02-08 16:46:52,247, data_manager.py, 83, INFO, Saving data for FDX
# 2025-02-08 16:46:56,046, data_manager.py, 83, INFO, Saving data for FE
# 2025-02-08 16:46:58,574, data_manager.py, 83, INFO, Saving data for FFIV
# 2025-02-08 16:47:01,203, data_manager.py, 83, INFO, Saving data for FI
# 2025-02-08 16:47:05,398, data_manager.py, 83, INFO, Saving data for FICO
# 2025-02-08 16:47:09,942, data_manager.py, 83, INFO, Saving data for FIS
# 2025-02-08 16:47:14,106, data_manager.py, 83, INFO, Saving data for FITB
# 2025-02-08 16:47:16,617, data_manager.py, 83, INFO, Saving data for FLT
# 2025-02-08 16:47:19,148, data_manager.py, 83, INFO, Saving data for FMC
# 2025-02-08 16:47:21,546, data_manager.py, 83, INFO, Saving data for FOX
# 2025-02-08 16:47:23,806, data_manager.py, 83, INFO, Saving data for FOXA
# 2025-02-08 16:47:26,061, data_manager.py, 83, INFO, Saving data for FRT
# 2025-02-08 16:47:28,741, data_manager.py, 83, INFO, Saving data for FSLR
# 2025-02-08 16:47:31,466, data_manager.py, 83, INFO, Saving data for FTNT
# 2025-02-08 16:47:34,160, data_manager.py, 83, INFO, Saving data for FTV
# 2025-02-08 16:47:37,091, data_manager.py, 83, INFO, Saving data for GD
# 2025-02-08 16:47:40,039, data_manager.py, 83, INFO, Saving data for GE
# 2025-02-08 16:47:43,107, data_manager.py, 83, INFO, Saving data for GEHC
# 2025-02-08 16:47:45,684, data_manager.py, 83, INFO, Saving data for GEN
# 2025-02-08 16:47:48,623, data_manager.py, 83, INFO, Saving data for GILD
# 2025-02-08 16:47:51,072, data_manager.py, 83, INFO, Saving data for GIS
# 2025-02-08 16:47:54,587, data_manager.py, 83, INFO, Saving data for GL
# 2025-02-08 16:47:57,140, data_manager.py, 83, INFO, Saving data for GLW
# 2025-02-08 16:47:59,504, data_manager.py, 83, INFO, Saving data for GM
# 2025-02-08 16:48:01,893, data_manager.py, 83, INFO, Saving data for GNRC
# 2025-02-08 16:48:04,512, data_manager.py, 83, INFO, Saving data for GOOG
# 2025-02-08 16:48:07,196, data_manager.py, 83, INFO, Saving data for GOOGL
# 2025-02-08 16:48:10,107, data_manager.py, 83, INFO, Saving data for GPC
# 2025-02-08 16:48:12,825, data_manager.py, 83, INFO, Saving data for GPN
# 2025-02-08 16:48:15,360, data_manager.py, 83, INFO, Saving data for GRMN
# 2025-02-08 16:48:18,200, data_manager.py, 83, INFO, Saving data for GS
# 2025-02-08 16:48:20,583, data_manager.py, 83, INFO, Saving data for GWW
# 2025-02-08 16:48:23,289, data_manager.py, 83, INFO, Saving data for HAL
# 2025-02-08 16:48:25,782, data_manager.py, 83, INFO, Saving data for HAS
# 2025-02-08 16:48:28,629, data_manager.py, 83, INFO, Saving data for HBAN
# 2025-02-08 16:48:31,272, data_manager.py, 83, INFO, Saving data for HCA
# 2025-02-08 16:48:33,467, data_manager.py, 83, INFO, Saving data for HD
# 2025-02-08 16:48:35,840, data_manager.py, 83, INFO, Saving data for HES
# 2025-02-08 16:48:38,312, data_manager.py, 83, INFO, Saving data for HIG
# 2025-02-08 16:48:41,389, data_manager.py, 83, INFO, Saving data for HII
# 2025-02-08 16:48:44,090, data_manager.py, 83, INFO, Saving data for HLT
# 2025-02-08 16:48:46,764, data_manager.py, 83, INFO, Saving data for HOLX
# 2025-02-08 16:48:49,537, data_manager.py, 83, INFO, Saving data for HON
# 2025-02-08 16:48:51,821, data_manager.py, 83, INFO, Saving data for HPE
# 2025-02-08 16:48:54,428, data_manager.py, 83, INFO, Saving data for HPQ
# 2025-02-08 16:48:57,501, data_manager.py, 83, INFO, Saving data for HRL
# 2025-02-08 16:49:00,263, data_manager.py, 83, INFO, Saving data for HSIC
# 2025-02-08 16:49:03,011, data_manager.py, 83, INFO, Saving data for HST
# 2025-02-08 16:49:05,351, data_manager.py, 83, INFO, Saving data for HSY
# 2025-02-08 16:49:07,477, data_manager.py, 83, INFO, Saving data for HUBB
# 2025-02-08 16:49:09,766, data_manager.py, 83, INFO, Saving data for HUM
# 2025-02-08 16:49:12,186, data_manager.py, 83, INFO, Saving data for HWM
# 2025-02-08 16:49:15,921, data_manager.py, 83, INFO, Saving data for IBM
# 2025-02-08 16:49:23,380, data_manager.py, 83, INFO, Saving data for ICE
# 2025-02-08 16:49:28,008, data_manager.py, 83, INFO, Saving data for IDXX
# 2025-02-08 16:49:32,392, data_manager.py, 83, INFO, Saving data for IEX
# 2025-02-08 16:49:36,467, data_manager.py, 83, INFO, Saving data for IFF
# 2025-02-08 16:49:40,175, data_manager.py, 83, INFO, Saving data for ILMN
# 2025-02-08 16:49:42,747, data_manager.py, 83, INFO, Saving data for INCY
# 2025-02-08 16:49:45,752, data_manager.py, 83, INFO, Saving data for INTC
# 2025-02-08 16:49:49,881, data_manager.py, 83, INFO, Saving data for INTU
# 2025-02-08 16:49:52,356, data_manager.py, 83, INFO, Saving data for INVH
# 2025-02-08 16:49:55,055, data_manager.py, 83, INFO, Saving data for IP
# 2025-02-08 16:49:57,839, data_manager.py, 83, INFO, Saving data for IPG
# 2025-02-08 16:50:00,763, data_manager.py, 83, INFO, Saving data for IQV
# 2025-02-08 16:50:03,584, data_manager.py, 83, INFO, Saving data for IR
# 2025-02-08 16:50:06,180, data_manager.py, 83, INFO, Saving data for IRM
# 2025-02-08 16:50:08,926, data_manager.py, 83, INFO, Saving data for ISRG
# 2025-02-08 16:50:11,498, data_manager.py, 83, INFO, Saving data for IT
# 2025-02-08 16:50:14,240, data_manager.py, 83, INFO, Saving data for ITW
# 2025-02-08 16:50:17,049, data_manager.py, 83, INFO, Saving data for IVZ
# 2025-02-08 16:50:19,959, data_manager.py, 83, INFO, Saving data for J
# 2025-02-08 16:50:22,692, data_manager.py, 83, INFO, Saving data for JBHT
# 2025-02-08 16:50:25,522, data_manager.py, 83, INFO, Saving data for JBL
# 2025-02-08 16:50:28,219, data_manager.py, 83, INFO, Saving data for JCI
# 2025-02-08 16:50:30,957, data_manager.py, 83, INFO, Saving data for JKHY
# 2025-02-08 16:50:33,426, data_manager.py, 83, INFO, Saving data for JNJ
# 2025-02-08 16:50:35,871, data_manager.py, 83, INFO, Saving data for JNPR
# 2025-02-08 16:50:38,687, data_manager.py, 83, INFO, Saving data for JPM
# 2025-02-08 16:50:40,845, data_manager.py, 83, INFO, Saving data for K
# 2025-02-08 16:50:42,995, data_manager.py, 83, INFO, Saving data for KDP
# 2025-02-08 16:50:45,278, data_manager.py, 83, INFO, Saving data for KEY
# 2025-02-08 16:50:47,985, data_manager.py, 83, INFO, Saving data for KEYS
# 2025-02-08 16:50:50,251, data_manager.py, 83, INFO, Saving data for KHC
# 2025-02-08 16:50:52,622, data_manager.py, 83, INFO, Saving data for KIM
# 2025-02-08 16:50:54,879, data_manager.py, 83, INFO, Saving data for KLAC
# 2025-02-08 16:50:57,062, data_manager.py, 83, INFO, Saving data for KMB
# 2025-02-08 16:50:59,369, data_manager.py, 83, INFO, Saving data for KMI
# 2025-02-08 16:51:01,921, data_manager.py, 83, INFO, Saving data for KMX
# 2025-02-08 16:51:04,528, data_manager.py, 83, INFO, Saving data for KO
# 2025-02-08 16:51:06,909, data_manager.py, 83, INFO, Saving data for KR
# 2025-02-08 16:51:10,002, data_manager.py, 83, INFO, Saving data for KVUE
# 2025-02-08 16:51:12,514, data_manager.py, 83, INFO, Saving data for L
# 2025-02-08 16:51:17,564, data_manager.py, 83, INFO, Saving data for LDOS
# 2025-02-08 16:51:21,448, data_manager.py, 83, INFO, Saving data for LEN
# 2025-02-08 16:51:24,038, data_manager.py, 83, INFO, Saving data for LH
# 2025-02-08 16:51:26,450, data_manager.py, 83, INFO, Saving data for LHX
# 2025-02-08 16:51:31,402, data_manager.py, 83, INFO, Saving data for LIN
# 2025-02-08 16:51:35,568, data_manager.py, 83, INFO, Saving data for LKQ
# 2025-02-08 16:51:38,698, data_manager.py, 83, INFO, Saving data for LLY
# 2025-02-08 16:51:41,374, data_manager.py, 83, INFO, Saving data for LMT
# 2025-02-08 16:51:43,926, data_manager.py, 83, INFO, Saving data for LNT
# 2025-02-08 16:51:46,273, data_manager.py, 83, INFO, Saving data for LOW
# 2025-02-08 16:51:49,281, data_manager.py, 83, INFO, Saving data for LRCX
# 2025-02-08 16:51:52,737, data_manager.py, 83, INFO, Saving data for LULU
# 2025-02-08 16:51:55,605, data_manager.py, 83, INFO, Saving data for LUV
# 2025-02-08 16:51:58,733, data_manager.py, 83, INFO, Saving data for LVS
# 2025-02-08 16:52:01,670, data_manager.py, 83, INFO, Saving data for LW
# 2025-02-08 16:52:04,510, data_manager.py, 83, INFO, Saving data for LYB
# 2025-02-08 16:52:07,355, data_manager.py, 83, INFO, Saving data for LYV
# 2025-02-08 16:52:09,635, data_manager.py, 83, INFO, Saving data for MA
# 2025-02-08 16:52:11,985, data_manager.py, 83, INFO, Saving data for MAA
# 2025-02-08 16:52:14,343, data_manager.py, 83, INFO, Saving data for MAR
# 2025-02-08 16:52:17,110, data_manager.py, 83, INFO, Saving data for MAS
# 2025-02-08 16:52:19,310, data_manager.py, 83, INFO, Saving data for MCD
# 2025-02-08 16:52:21,609, data_manager.py, 83, INFO, Saving data for MCHP
# 2025-02-08 16:52:23,940, data_manager.py, 83, INFO, Saving data for MCK
# 2025-02-08 16:52:26,214, data_manager.py, 83, INFO, Saving data for MCO
# 2025-02-08 16:52:28,927, data_manager.py, 83, INFO, Saving data for MDLZ
# 2025-02-08 16:52:31,451, data_manager.py, 83, INFO, Saving data for MDT
# 2025-02-08 16:52:34,402, data_manager.py, 83, INFO, Saving data for MET
# 2025-02-08 16:52:36,671, data_manager.py, 83, INFO, Saving data for META
# 2025-02-08 16:52:39,514, data_manager.py, 83, INFO, Saving data for MGM
# 2025-02-08 16:52:41,775, data_manager.py, 83, INFO, Saving data for MHK
# 2025-02-08 16:52:44,097, data_manager.py, 83, INFO, Saving data for MKC
# 2025-02-08 16:52:46,451, data_manager.py, 83, INFO, Saving data for MKTX
# 2025-02-08 16:52:49,043, data_manager.py, 83, INFO, Saving data for MLM
# 2025-02-08 16:52:51,346, data_manager.py, 83, INFO, Saving data for MMC
# 2025-02-08 16:52:53,901, data_manager.py, 83, INFO, Saving data for MMM
# 2025-02-08 16:52:56,421, data_manager.py, 83, INFO, Saving data for MNST
# 2025-02-08 16:52:58,817, data_manager.py, 83, INFO, Saving data for MO
# 2025-02-08 16:53:00,875, data_manager.py, 83, INFO, Saving data for MOH
# 2025-02-08 16:53:03,052, data_manager.py, 83, INFO, Saving data for MOS
# 2025-02-08 16:53:05,375, data_manager.py, 83, INFO, Saving data for MPC
# 2025-02-08 16:53:08,298, data_manager.py, 83, INFO, Saving data for MPWR
# 2025-02-08 16:53:10,412, data_manager.py, 83, INFO, Saving data for MRK
# 2025-02-08 16:53:12,740, data_manager.py, 83, INFO, Saving data for MRNA
# 2025-02-08 16:53:14,841, data_manager.py, 83, INFO, Saving data for MRO
# 2025-02-08 16:53:17,638, data_manager.py, 83, INFO, Saving data for MS
# 2025-02-08 16:53:20,052, data_manager.py, 83, INFO, Saving data for MSCI
# 2025-02-08 16:53:23,025, data_manager.py, 83, INFO, Saving data for MSFT
# 2025-02-08 16:53:25,383, data_manager.py, 83, INFO, Saving data for MSI
# 2025-02-08 16:53:28,114, data_manager.py, 83, INFO, Saving data for MTB
# 2025-02-08 16:53:30,398, data_manager.py, 83, INFO, Saving data for MTCH
# 2025-02-08 16:53:32,626, data_manager.py, 83, INFO, Saving data for MTD
# 2025-02-08 16:53:35,064, data_manager.py, 83, INFO, Saving data for MU
# 2025-02-08 16:53:37,779, data_manager.py, 83, INFO, Saving data for NCLH
# 2025-02-08 16:53:40,321, data_manager.py, 83, INFO, Saving data for NDAQ
# 2025-02-08 16:53:42,608, data_manager.py, 83, INFO, Saving data for NDSN
# 2025-02-08 16:53:45,148, data_manager.py, 83, INFO, Saving data for NEE
# 2025-02-08 16:53:47,456, data_manager.py, 83, INFO, Saving data for NEM
# 2025-02-08 16:53:50,292, data_manager.py, 83, INFO, Saving data for NFLX
# 2025-02-08 16:53:53,004, data_manager.py, 83, INFO, Saving data for NI
# 2025-02-08 16:53:55,556, data_manager.py, 83, INFO, Saving data for NKE
# 2025-02-08 16:53:57,871, data_manager.py, 83, INFO, Saving data for NOC
# 2025-02-08 16:54:00,451, data_manager.py, 83, INFO, Saving data for NOW
# 2025-02-08 16:54:03,094, data_manager.py, 83, INFO, Saving data for NRG
# 2025-02-08 16:54:05,599, data_manager.py, 83, INFO, Saving data for NSC
# 2025-02-08 16:54:08,099, data_manager.py, 83, INFO, Saving data for NTAP
# 2025-02-08 16:54:10,692, data_manager.py, 83, INFO, Saving data for NTRS
# 2025-02-08 16:54:13,272, data_manager.py, 83, INFO, Saving data for NUE
# 2025-02-08 16:54:15,475, data_manager.py, 83, INFO, Saving data for NVDA
# 2025-02-08 16:54:17,666, data_manager.py, 83, INFO, Saving data for NVR
# 2025-02-08 16:54:19,908, data_manager.py, 83, INFO, Saving data for NWS
# 2025-02-08 16:54:22,362, data_manager.py, 83, INFO, Saving data for NWSA
# 2025-02-08 16:54:24,658, data_manager.py, 83, INFO, Saving data for NXPI
# 2025-02-08 16:54:26,928, data_manager.py, 83, INFO, Saving data for O
# 2025-02-08 16:54:29,064, data_manager.py, 83, INFO, Saving data for ODFL
# 2025-02-08 16:54:31,319, data_manager.py, 83, INFO, Saving data for OKE
# 2025-02-08 16:54:33,742, data_manager.py, 83, INFO, Saving data for OMC
# 2025-02-08 16:54:36,205, data_manager.py, 83, INFO, Saving data for ON
# 2025-02-08 16:54:38,588, data_manager.py, 83, INFO, Saving data for ORCL
# 2025-02-08 16:54:41,093, data_manager.py, 83, INFO, Saving data for ORLY
# 2025-02-08 16:54:43,366, data_manager.py, 83, INFO, Saving data for OTIS
# 2025-02-08 16:54:45,468, data_manager.py, 83, INFO, Saving data for OXY
# 2025-02-08 16:54:47,849, data_manager.py, 83, INFO, Saving data for PANW
# 2025-02-08 16:54:50,014, data_manager.py, 83, INFO, Saving data for PARA
# 2025-02-08 16:54:52,080, data_manager.py, 83, INFO, Saving data for PAYC
# 2025-02-08 16:54:55,409, data_manager.py, 83, INFO, Saving data for PAYX
# 2025-02-08 16:54:58,554, data_manager.py, 83, INFO, Saving data for PCAR
# 2025-02-08 16:55:01,449, data_manager.py, 83, INFO, Saving data for PCG
# 2025-02-08 16:55:03,808, data_manager.py, 83, INFO, Saving data for PEAK
# 2025-02-08 16:55:06,052, data_manager.py, 83, INFO, Saving data for PEG
# 2025-02-08 16:55:08,689, data_manager.py, 83, INFO, Saving data for PEP
# 2025-02-08 16:55:11,187, data_manager.py, 83, INFO, Saving data for PFE
# 2025-02-08 16:55:14,061, data_manager.py, 83, INFO, Saving data for PFG
# 2025-02-08 16:55:16,595, data_manager.py, 83, INFO, Saving data for PG
# 2025-02-08 16:55:19,120, data_manager.py, 83, INFO, Saving data for PGR
# 2025-02-08 16:55:21,474, data_manager.py, 83, INFO, Saving data for PH
# 2025-02-08 16:55:23,826, data_manager.py, 83, INFO, Saving data for PHM
# 2025-02-08 16:55:26,537, data_manager.py, 83, INFO, Saving data for PKG
# 2025-02-08 16:55:29,106, data_manager.py, 83, INFO, Saving data for PLD
# 2025-02-08 16:55:31,836, data_manager.py, 83, INFO, Saving data for PM
# 2025-02-08 16:55:34,521, data_manager.py, 83, INFO, Saving data for PNC
# 2025-02-08 16:55:37,501, data_manager.py, 83, INFO, Saving data for PNR
# 2025-02-08 16:55:40,369, data_manager.py, 83, INFO, Saving data for PNW
# 2025-02-08 16:55:43,050, data_manager.py, 83, INFO, Saving data for PODD
# 2025-02-08 16:55:45,568, data_manager.py, 83, INFO, Saving data for POOL
# 2025-02-08 16:55:47,839, data_manager.py, 83, INFO, Saving data for PPG
# 2025-02-08 16:55:50,140, data_manager.py, 83, INFO, Saving data for PPL
# 2025-02-08 16:55:52,592, data_manager.py, 83, INFO, Saving data for PRU
# 2025-02-08 16:55:54,892, data_manager.py, 83, INFO, Saving data for PSA
# 2025-02-08 16:55:57,189, data_manager.py, 83, INFO, Saving data for PSX
# 2025-02-08 16:55:59,586, data_manager.py, 83, INFO, Saving data for PTC
# 2025-02-08 16:56:02,004, data_manager.py, 83, INFO, Saving data for PWR
# 2025-02-08 16:56:04,611, data_manager.py, 83, INFO, Saving data for PXD
# 2025-02-08 16:56:07,217, data_manager.py, 83, INFO, Saving data for PYPL
# 2025-02-08 16:56:10,280, data_manager.py, 83, INFO, Saving data for QCOM
# 2025-02-08 16:56:13,500, data_manager.py, 83, INFO, Saving data for QRVO
# 2025-02-08 16:56:16,800, data_manager.py, 83, INFO, Saving data for RCL
# 2025-02-08 16:56:20,399, data_manager.py, 83, INFO, Saving data for REG
# 2025-02-08 16:56:22,616, data_manager.py, 83, INFO, Saving data for REGN
# 2025-02-08 16:56:25,229, data_manager.py, 83, INFO, Saving data for RF
# 2025-02-08 16:56:27,675, data_manager.py, 83, INFO, Saving data for RHI
# 2025-02-08 16:56:30,195, data_manager.py, 83, INFO, Saving data for RJF
# 2025-02-08 16:56:33,030, data_manager.py, 83, INFO, Saving data for RL
# 2025-02-08 16:56:35,792, data_manager.py, 83, INFO, Saving data for RMD
# 2025-02-08 16:56:38,503, data_manager.py, 83, INFO, Saving data for ROK
# 2025-02-08 16:56:41,066, data_manager.py, 83, INFO, Saving data for ROL
# 2025-02-08 16:56:43,628, data_manager.py, 83, INFO, Saving data for ROP
# 2025-02-08 16:56:46,517, data_manager.py, 83, INFO, Saving data for ROST
# 2025-02-08 16:56:48,820, data_manager.py, 83, INFO, Saving data for RSG
# 2025-02-08 16:56:51,634, data_manager.py, 83, INFO, Saving data for RTX
# 2025-02-08 16:56:54,660, data_manager.py, 83, INFO, Saving data for RVTY
# 2025-02-08 16:56:57,464, data_manager.py, 83, INFO, Saving data for SBAC
# 2025-02-08 16:57:00,329, data_manager.py, 83, INFO, Saving data for SBUX
# 2025-02-08 16:57:02,793, data_manager.py, 83, INFO, Saving data for SCHW
# 2025-02-08 16:57:05,310, data_manager.py, 83, INFO, Saving data for SHW
# 2025-02-08 16:57:08,303, data_manager.py, 83, INFO, Saving data for SJM
# 2025-02-08 16:57:10,530, data_manager.py, 83, INFO, Saving data for SLB
# 2025-02-08 16:57:13,062, data_manager.py, 83, INFO, Saving data for SNA
# 2025-02-08 16:57:16,185, data_manager.py, 83, INFO, Saving data for SNPS
# 2025-02-08 16:57:19,997, data_manager.py, 83, INFO, Saving data for SO
# 2025-02-08 16:57:22,655, data_manager.py, 83, INFO, Saving data for SPG
# 2025-02-08 16:57:25,593, data_manager.py, 83, INFO, Saving data for SPGI
# 2025-02-08 16:57:28,595, data_manager.py, 83, INFO, Saving data for SRE
# 2025-02-08 16:57:31,687, data_manager.py, 83, INFO, Saving data for STE
# 2025-02-08 16:57:34,687, data_manager.py, 83, INFO, Saving data for STLD
# 2025-02-08 16:57:37,134, data_manager.py, 83, INFO, Saving data for STT
# 2025-02-08 16:57:39,407, data_manager.py, 83, INFO, Saving data for STX
# 2025-02-08 16:57:41,786, data_manager.py, 83, INFO, Saving data for STZ
# 2025-02-08 16:57:44,263, data_manager.py, 83, INFO, Saving data for SWK
# 2025-02-08 16:57:46,798, data_manager.py, 83, INFO, Saving data for SWKS
# 2025-02-08 16:57:49,573, data_manager.py, 83, INFO, Saving data for SYF
# 2025-02-08 16:57:52,254, data_manager.py, 83, INFO, Saving data for SYK
# 2025-02-08 16:57:54,902, data_manager.py, 83, INFO, Saving data for SYY
# 2025-02-08 16:57:57,372, data_manager.py, 83, INFO, Saving data for T
# 2025-02-08 16:57:59,632, data_manager.py, 83, INFO, Saving data for TAP
# 2025-02-08 16:58:01,940, data_manager.py, 83, INFO, Saving data for TDG
# 2025-02-08 16:58:04,374, data_manager.py, 83, INFO, Saving data for TDY
# 2025-02-08 16:58:06,822, data_manager.py, 83, INFO, Saving data for TECH
# 2025-02-08 16:58:09,345, data_manager.py, 83, INFO, Saving data for TEL
# 2025-02-08 16:58:11,694, data_manager.py, 83, INFO, Saving data for TER
# 2025-02-08 16:58:14,344, data_manager.py, 83, INFO, Saving data for TFC
# 2025-02-08 16:58:16,900, data_manager.py, 83, INFO, Saving data for TFX
# 2025-02-08 16:58:19,815, data_manager.py, 83, INFO, Saving data for TGT
# 2025-02-08 16:58:22,587, data_manager.py, 83, INFO, Saving data for TJX
# 2025-02-08 16:58:25,546, data_manager.py, 83, INFO, Saving data for TMO
# 2025-02-08 16:58:28,100, data_manager.py, 83, INFO, Saving data for TMUS
# 2025-02-08 16:58:30,441, data_manager.py, 83, INFO, Saving data for TPR
# 2025-02-08 16:58:32,675, data_manager.py, 83, INFO, Saving data for TRGP
# 2025-02-08 16:58:35,134, data_manager.py, 83, INFO, Saving data for TRMB
# 2025-02-08 16:58:38,392, data_manager.py, 83, INFO, Saving data for TROW
# 2025-02-08 16:58:41,069, data_manager.py, 83, INFO, Saving data for TRV
# 2025-02-08 16:58:43,587, data_manager.py, 83, INFO, Saving data for TSCO
# 2025-02-08 16:58:46,814, data_manager.py, 83, INFO, Saving data for TSLA
# 2025-02-08 16:58:49,590, data_manager.py, 83, INFO, Saving data for TSN
# 2025-02-08 16:58:52,902, data_manager.py, 83, INFO, Saving data for TT
# 2025-02-08 16:58:55,713, data_manager.py, 83, INFO, Saving data for TTWO
# 2025-02-08 16:58:58,356, data_manager.py, 83, INFO, Saving data for TXN
# 2025-02-08 16:59:00,967, data_manager.py, 83, INFO, Saving data for TXT
# 2025-02-08 16:59:03,531, data_manager.py, 83, INFO, Saving data for TYL
# 2025-02-08 16:59:06,152, data_manager.py, 83, INFO, Saving data for UAL
# 2025-02-08 16:59:08,840, data_manager.py, 83, INFO, Saving data for UBER
# 2025-02-08 16:59:11,246, data_manager.py, 83, INFO, Saving data for UDR
# 2025-02-08 16:59:13,624, data_manager.py, 83, INFO, Saving data for UHS
# 2025-02-08 16:59:15,936, data_manager.py, 83, INFO, Saving data for ULTA
# 2025-02-08 16:59:18,211, data_manager.py, 83, INFO, Saving data for UNH
# 2025-02-08 16:59:20,744, data_manager.py, 83, INFO, Saving data for UNP
# 2025-02-08 16:59:23,165, data_manager.py, 83, INFO, Saving data for UPS
# 2025-02-08 16:59:25,571, data_manager.py, 83, INFO, Saving data for URI
# 2025-02-08 16:59:28,100, data_manager.py, 83, INFO, Saving data for USB
# 2025-02-08 16:59:30,636, data_manager.py, 83, INFO, Saving data for V
# 2025-02-08 16:59:33,298, data_manager.py, 83, INFO, Saving data for VFC
# 2025-02-08 16:59:35,873, data_manager.py, 83, INFO, Saving data for VICI
# 2025-02-08 16:59:38,066, data_manager.py, 83, INFO, Saving data for VLO
# 2025-02-08 16:59:40,378, data_manager.py, 83, INFO, Saving data for VLTO
# 2025-02-08 16:59:42,830, data_manager.py, 83, INFO, Saving data for VMC
# 2025-02-08 16:59:45,346, data_manager.py, 83, INFO, Saving data for VRSK
# 2025-02-08 16:59:47,682, data_manager.py, 83, INFO, Saving data for VRSN
# 2025-02-08 16:59:50,237, data_manager.py, 83, INFO, Saving data for VRTX
# 2025-02-08 16:59:52,446, data_manager.py, 83, INFO, Saving data for VTR
# 2025-02-08 16:59:54,983, data_manager.py, 83, INFO, Saving data for VTRS
# 2025-02-08 16:59:57,170, data_manager.py, 83, INFO, Saving data for VZ
# 2025-02-08 16:59:59,552, data_manager.py, 83, INFO, Saving data for WAB
# 2025-02-08 17:00:02,132, data_manager.py, 83, INFO, Saving data for WAT
# 2025-02-08 17:00:04,901, data_manager.py, 83, INFO, Saving data for WBA
# 2025-02-08 17:00:07,625, data_manager.py, 83, INFO, Saving data for WBD
# 2025-02-08 17:00:10,439, data_manager.py, 83, INFO, Saving data for WDC
# 2025-02-08 17:00:13,855, data_manager.py, 83, INFO, Saving data for WEC
# 2025-02-08 17:00:16,147, data_manager.py, 83, INFO, Saving data for WELL
# 2025-02-08 17:00:18,668, data_manager.py, 83, INFO, Saving data for WFC
# 2025-02-08 17:00:21,178, data_manager.py, 83, INFO, Saving data for WHR
# 2025-02-08 17:00:23,976, data_manager.py, 83, INFO, Saving data for WM
# 2025-02-08 17:00:26,325, data_manager.py, 83, INFO, Saving data for WMB
# 2025-02-08 17:00:28,759, data_manager.py, 83, INFO, Saving data for WMT
# 2025-02-08 17:00:31,677, data_manager.py, 83, INFO, Saving data for WRB
# 2025-02-08 17:00:34,675, data_manager.py, 83, INFO, Saving data for WRK
# 2025-02-08 17:00:37,255, data_manager.py, 83, INFO, Saving data for WST
# 2025-02-08 17:00:39,932, data_manager.py, 83, INFO, Saving data for WTW
# 2025-02-08 17:00:42,216, data_manager.py, 83, INFO, Saving data for WY
# 2025-02-08 17:00:44,425, data_manager.py, 83, INFO, Saving data for WYNN
# 2025-02-08 17:00:46,689, data_manager.py, 83, INFO, Saving data for XEL
# 2025-02-08 17:00:48,859, data_manager.py, 83, INFO, Saving data for XOM
# 2025-02-08 17:00:50,966, data_manager.py, 83, INFO, Saving data for XRAY
# 2025-02-08 17:00:53,145, data_manager.py, 83, INFO, Saving data for XYL
# 2025-02-08 17:00:55,308, data_manager.py, 83, INFO, Saving data for YUM
# 2025-02-08 17:00:57,516, data_manager.py, 83, INFO, Saving data for ZBH
# 2025-02-08 17:00:59,841, data_manager.py, 83, INFO, Saving data for ZBRA
# 2025-02-08 17:01:01,932, data_manager.py, 83, INFO, Saving data for ZION
# 2025-02-08 17:01:04,000, data_manager.py, 83, INFO, Saving data for ZTS

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2025-02-08 17:01:06,180, data_manager.py, 114, INFO, Creating features data.
# 2025-02-08 17:01:06,182, data_manager.py, 124, INFO, Loading price data from ../../05_src/data/prices/
# c:\Users\Teresa - School\anaconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\core.py:5310: UserWarning: New index has same name as existing, this is a no-op.
#   warnings.warn(
# 2025-02-08 17:01:11,196, data_manager.py, 133, INFO, Creating features
# c:\Users\Teresa - School\Documents\GitHub\production\01_materials\labs\../../05_src\data_manager.py:136: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd.groupby('Ticker', group_keys=False)
# 2025-02-08 17:01:11,289, data_manager.py, 158, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
